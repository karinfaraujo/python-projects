# %% [markdown]
# <a href="https://colab.research.google.com/github/karinfaraujo/python-projects/blob/main/Python_para_ML_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python para Machine Learning - 4**

# %% [markdown]
# ##**Dicionários**

# %% [markdown]
# São objetos no Python similares a conjuntos, mas permitem que sejam colocados chaves de referência para cada item. São definidos utilizando chaves **{ }**.

# %%
dicionario = {'nome': 'Karin', 'idade': 31, 'funcao_favorita': len}

# %%
dicionario.values()
# Out:
# dict_values(['Karin', 31, <built-in function len>])

# %%
# Adicionando novos itens a um dicionário.
dicionario['musica_favorita'] = 'Highway Blues'

# %%
dicionario
# Out:
# {'nome': 'Karin',
#  'idade': 31,
#  'funcao_favorita': <function len(obj, /)>,
#  'musica_favorita': 'Highway Blues'}

# %%
# Passar uma lista de argumentos para uma função.
parametros = {'loc': 2, 'scale': 3, 'size': 12}

# %%
import numpy as np

# %%
x = np.random.normal(**parametros)
print(x)
# Out:
# [ 0.15668931 -4.50857018  0.88584173  1.44528895  3.45538305  4.4682155
#  -2.3151845   3.63143095  4.74055074 -1.51590969  5.70533938  0.380465  ]

# %%
# Solução similar quando se quer passar listas como argumentos de função.
lista = [4, 2, 15]
x = np.random.normal(*lista)
print(x)
# Out:
# [ 5.33274782  5.63491588  2.0665791   7.54783589  5.59643721 -0.19547281
#   2.64548537  3.24114997  1.86472788  3.77131079 -0.94612434  5.02351023
#   4.60221453  3.6893726   5.12502293]

# %%
np.random.uniform(0, 10, 3).round(1)
# Out:
# array([ 2.5, 10. ,  7.8])

# %% [markdown]
# ##**A Biblioteca Pandas**

# %% [markdown]
# É a principal biblioteca em Python para se trabalhar com conjunto de dados. Ela oferece diversos objetos e muitas funções que facilitam a importação, seleção, alteração e filtragem de conjuntos de dados.

# %%
import pandas as pd

# %%
dicionario = {'Alice': np.random.uniform(5, 10,4).round(1),
              'Bruno': np.random.uniform(0,7, 4).round(1),
              'Carla': np.random.uniform(3, 7, 4).round(1),
              'David': np.random.uniform(0, 10, 4).round(1),
              'Emily': np.random.uniform(8, 10, 4).round(1),}

# %%
provas = pd.DataFrame(dicionario)

# %%
provas.index = ['P1', 'P2', 'P3', 'P4']

# %%
provas = provas.transpose()

# %%
provas
# Out:
#         P1   P2   P3   P4
# Alice  8.7  9.3  7.6  9.0
# Bruno  2.3  6.7  0.2  6.5
# Carla  3.1  4.7  6.8  6.6
# David  0.3  1.9  9.5  0.3
# Emily  9.8  9.6  8.6  8.8

# %%
provas.tail(2)
# Out:
#         P1   P2   P3   P4   MF
# David  0.3  1.9  9.5  0.3  3.0
# Emily  9.8  9.6  8.6  8.8  9.2

# %%
provas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Alice to Emily
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   P1      5 non-null      float64
#  1   P2      5 non-null      float64
#  2   P3      5 non-null      float64
#  3   P4      5 non-null      float64
#  4   MF      5 non-null      float64
# dtypes: float64(5)
# memory usage: 412.0+ bytes

# %%
provas.T.describe()
# Out:
#           Alice     Bruno     Carla     David     Emily
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   8.640000  3.920000  5.300000  3.000000  9.200000
# std    0.642651  2.777049  1.511622  3.809199  0.509902
# min    7.600000  0.200000  3.100000  0.300000  8.600000
# 25%    8.600000  2.300000  4.700000  0.300000  8.800000
# 50%    8.700000  3.900000  5.300000  1.900000  9.200000
# 75%    9.000000  6.500000  6.600000  3.000000  9.600000
# max    9.300000  6.700000  6.800000  9.500000  9.800000

# %%
provas.shape
# Out:
# (5, 5)

# %%
provas
# Out:
#         P1   P2   P3   P4   MF
# Alice  8.7  9.3  7.6  9.0  8.6
# Bruno  2.3  6.7  0.2  6.5  3.9
# Carla  3.1  4.7  6.8  6.6  5.3
# David  0.3  1.9  9.5  0.3  3.0
# Emily  9.8  9.6  8.6  8.8  9.2

# %%
provas['MF'] = provas.mean(axis = 1).round(1)

# %%
provas
# Out:
#         P1   P2   P3   P4   MF
# Alice  8.7  9.3  7.6  9.0  8.6
# Bruno  2.3  6.7  0.2  6.5  3.9
# Carla  3.1  4.7  6.8  6.6  5.3
# David  0.3  1.9  9.5  0.3  3.0
# Emily  9.8  9.6  8.6  8.8  9.2

# %% [markdown]
# Criando uma nova variável personalizada, em que é definida como 'Aprovado' se a variável Média for maior ou igual a 5, e 'Reprovado' no caso contrário:

# %%
def aux(x):
    if x >= 5:
        return 'Aprovado'
    else:
        return 'Reprovado'
provas['Situação'] = provas['MF'].apply(aux)

# %%
provas
# Out:
#         P1   P2   P3   P4   MF   Situação
# Alice  8.7  9.3  7.6  9.0  8.6   Aprovado
# Bruno  2.3  6.7  0.2  6.5  3.9  Reprovado
# Carla  3.1  4.7  6.8  6.6  5.3   Aprovado
# David  0.3  1.9  9.5  0.3  3.0  Reprovado
# Emily  9.8  9.6  8.6  8.8  9.2   Aprovado

# %% [markdown]
# Ordenando um conjunto de dados:

# %%
provas.sort_values('MF')
# Out:
#         P1   P2   P3   P4   MF   Situação
# David  0.3  1.9  9.5  0.3  3.0  Reprovado
# Bruno  2.3  6.7  0.2  6.5  3.9  Reprovado
# Carla  3.1  4.7  6.8  6.6  5.3   Aprovado
# Alice  8.7  9.3  7.6  9.0  8.6   Aprovado
# Emily  9.8  9.6  8.6  8.8  9.2   Aprovado

# %%
provas.sort_values('Situação')
# Out:
#         P1   P2   P3   P4   MF   Situação
# Alice  8.7  9.3  7.6  9.0  8.6   Aprovado
# Carla  3.1  4.7  6.8  6.6  5.3   Aprovado
# Emily  9.8  9.6  8.6  8.8  9.2   Aprovado
# Bruno  2.3  6.7  0.2  6.5  3.9  Reprovado
# David  0.3  1.9  9.5  0.3  3.0  Reprovado

# %% [markdown]
# O Pandas também oferece suporte a alguns gráficos, baseados na biblioteca Matplotlib. Basta chamar o método utilizando os dados adequados:

# %%
provas['Situação'].value_counts().plot(kind = 'bar', color = ['green', 'red'])
# Out:
# <Axes: >

# %%
provas['Situação'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Situação'>

# %%
provas[['P1', 'P2', 'P3', 'P4', 'MF']].plot(kind = 'box')
# Out:
# <Axes: >

# %%
provas[['P1', 'P2', 'P3', 'P4']].transpose().plot(kind = 'line')
# Out:
# <Axes: >

# %%
provas[['P1', 'P2', 'P3', 'P4', 'MF']].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3c139_row0_col0, #T_3c139_row1_col1, #T_3c139_row2_col2, #T_3c139_row3_col3, #T_3c139_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3c139_row0_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_3c139_row0_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_3c139_row0_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_3c139_row0_col4, #T_3c139_row4_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_3c139_row1_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_3c139_row1_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3c139_row1_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_3c139_row1_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_3c139_row2_col0, #T_3c139_row2_col1, #T_3c139_row2_col3, #T_3c139_row2_col4, #T_3c139_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3c139_row3_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_3c139_row3_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_3c139_row3_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_3c139_row4_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_3c139_row4_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_3c139_row4_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c139" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c139_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_3c139_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_3c139_level0_col2" class="col_heading level0 col2" >P3</th>
#       <th id="T_3c139_level0_col3" class="col_heading level0 col3" >P4</th>
#       <th id="T_3c139_level0_col4" class="col_heading level0 col4" >MF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c139_level0_row0" class="row_heading level0 row0" >P1</th>
#       <td id="T_3c139_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3c139_row0_col1" class="data row0 col1" >0.920545</td>
#       <td id="T_3c139_row0_col2" class="data row0 col2" >0.268544</td>
#       <td id="T_3c139_row0_col3" class="data row0 col3" >0.834126</td>
#       <td id="T_3c139_row0_col4" class="data row0 col4" >0.993696</td>
#     </tr>
#     <tr>
#       <th id="T_3c139_level0_row1" class="row_heading level0 row1" >P2</th>
#       <td id="T_3c139_row1_col0" class="data row1 col0" >0.920545</td>
#       <td id="T_3c139_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3c139_row1_col2" class="data row1 col2" >-0.125683</td>
#       <td id="T_3c139_row1_col3" class="data row1 col3" >0.929723</td>
#       <td id="T_3c139_row1_col4" class="data row1 col4" >0.885181</td>
#     </tr>
#     <tr>
#       <th id="T_3c139_level0_row2" class="row_heading level0 row2" >P3</th>
#       <td id="T_3c139_row2_col0" class="data row2 col0" >0.268544</td>
#       <td id="T_3c139_row2_col1" class="data row2 col1" >-0.125683</td>
#       <td id="T_3c139_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3c139_row2_col3" class="data row2 col3" >-0.210476</td>
#       <td id="T_3c139_row2_col4" class="data row2 col4" >0.331736</td>
#     </tr>
#     <tr>
#       <th id="T_3c139_level0_row3" class="row_heading level0 row3" >P4</th>
#       <td id="T_3c139_row3_col0" class="data row3 col0" >0.834126</td>
#       <td id="T_3c139_row3_col1" class="data row3 col1" >0.929723</td>
#       <td id="T_3c139_row3_col2" class="data row3 col2" >-0.210476</td>
#       <td id="T_3c139_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3c139_row3_col4" class="data row3 col4" >0.826920</td>
#     </tr>
#     <tr>
#       <th id="T_3c139_level0_row4" class="row_heading level0 row4" >MF</th>
#       <td id="T_3c139_row4_col0" class="data row4 col0" >0.993696</td>
#       <td id="T_3c139_row4_col1" class="data row4 col1" >0.885181</td>
#       <td id="T_3c139_row4_col2" class="data row4 col2" >0.331736</td>
#       <td id="T_3c139_row4_col3" class="data row4 col3" >0.826920</td>
#       <td id="T_3c139_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
provas[  provas['P1'] > 7]
# Out:
#         P1   P2   P3   P4   MF  Situação
# Alice  8.7  9.3  7.6  9.0  8.6  Aprovado
# Emily  9.8  9.6  8.6  8.8  9.2  Aprovado

# %% [markdown]
# ##**Importação de Dados**

# %% [markdown]
# ####Exemplo 1: Lendo arquivos da amostra do google Colab

# %%
import pandas as pd

# %%
casas = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
casas
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %% [markdown]
# #### Exemplo 2: Lendo arquivos xlsx direto do Github

# %%
url = 'https://raw.githubusercontent.com/ricardorocha86/Dados-Redes-Sociais/master/Social_Network_Ads.csv'
dados = pd.read_csv(url)
dados
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ## **PROJETO**: Lendo arquivos de uma webpage

# %%
url = 'https://pt.wikipedia.org/wiki/Salvador'
wiki = pd.read_html(url, decimal= ',', thousands= '.')

# %%
wiki[4]
# Out:
#          Dados climatológicos para Salvador (Ondina)  \
#                                                  Mês
# 0                    Temperatura máxima recorde (°C)
# 1                      Temperatura máxima média (°C)
# 2                  Temperatura média compensada (°C)
# 3                      Temperatura mínima média (°C)
# 4                    Temperatura mínima recorde (°C)
# 5                                  Precipitação (mm)
# 6                     Dias com precipitação (≥ 1 mm)
# 7                    Umidade relativa compensada (%)
# 8                                       Horas de sol
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Jan
# 0                                               34.3
# 1                                                 31
# 2                                               26.9
# 3                                               23.8
# 4                                               19.8
# 5                                               76.9
# 6                                                  9
# 7                                               78.7
# 8                                              234.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Fev
# 0                                               34.7
# 1                                               31.1
# 2                                               27.1
# 3                                                 24
# 4                                               19.5
# 5                                               98.7
# 6                                                  9
# 7                                               79.4
# 8                                              208.2
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Mar
# 0                                                 37
# 1                                               30.9
# 2                                               27.1
# 3                                               24.1
# 4                                               18.7
# 5                                              147.3
# 6                                                 11
# 7                                               80.6
# 8                                              225.5
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Abr
# 0                                               34.5
# 1                                               29.6
# 2                                               26.4
# 3                                               23.6
# 4                                               18.7
# 5                                              284.9
# 6                                                 16
# 7                                               83.3
# 8                                              185.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Mai
# 0                                               31.9
# 1                                               28.1
# 2                                               25.3
# 3                                               22.8
# 4                                                 18
# 5                                              302.2
# 6                                                 18
# 7                                               85.1
# 8                                              156.7
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Jun
# 0                                               30.6
# 1                                               27.1
# 2                                               24.3
# 3                                               21.9
# 4                                               18.2
# 5                                              237.6
# 6                                                 19
# 7                                               84.9
# 8                                              144.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Jul
# 0                                               30.7
# 1                                               26.6
# 2                                               23.7
# 3                                               21.1
# 4                                               17.5
# 5                                              194.1
# 6                                                 18
# 7                                               83.4
# 8                                              169.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Ago
# 0                                               31.3
# 1                                               26.7
# 2                                               23.6
# 3                                                 21
# 4                                               17.7
# 5                                              129.7
# 6                                                 16
# 7                                               82.1
# 8                                              190.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Set
# 0                                               30.7
# 1                                               27.7
# 2                                               24.3
# 3                                               21.5
# 4                                               17.6
# 5                                               99.3
# 6                                                 11
# 7                                               81.2
# 8                                              205.3
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Out
# 0                                               33.5
# 1                                               29.1
# 2                                               25.4
# 3                                               22.5
# 4                                               18.3
# 5                                                 91
# 6                                                  8
# 7                                                 80
# 8                                              226.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Nov
# 0                                               33.5
# 1                                               29.8
# 2                                               26.1
# 3                                               23.1
# 4                                               18.9
# 5                                              108.2
# 6                                                  8
# 7                                               80.4
# 8                                              202.9
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                       \
#                                                  Dez
# 0                                               34.3
# 1                                               30.6
# 2                                               26.6
# 3                                               23.5
# 4                                               19.8
# 5                                               63.4
# 6                                                  7
# 7                                               79.3
# 8                                              222.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#
#                                                  Ano
# 0                                                 37
# 1                                                 29
# 2                                               25.6
# 3                                               22.7
# 4                                               17.5
# 5                                            1 833,3
# 6                                                150
# 7                                               81.5
# 8                                            2 372,8
# 9  Fonte: INMET (normal climatológica de 1991-202...

# %%
salvador = wiki[4]

# %%
colunas = salvador.columns

# %%
colunas
# Out:
# MultiIndex([('Dados climatológicos para Salvador (Ondina)', 'Mês'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Jan'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Fev'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Mar'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Abr'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Mai'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Jun'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Jul'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Ago'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Set'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Out'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Nov'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Dez'),
#             ('Dados climatológicos para Salvador (Ondina)', 'Ano')],
#            )

# %%
cols = []
for i in range(len(colunas)):
    cols.append(colunas[i][1])
cols[0] = 'Medida'
print(cols)
# Out:
# ['Medida', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Ano']

# %%
salvador.columns = cols

# %%
salvador
# Out:
#                                               Medida  \
# 0                    Temperatura máxima recorde (°C)
# 1                      Temperatura máxima média (°C)
# 2                  Temperatura média compensada (°C)
# 3                      Temperatura mínima média (°C)
# 4                    Temperatura mínima recorde (°C)
# 5                                  Precipitação (mm)
# 6                     Dias com precipitação (≥ 1 mm)
# 7                    Umidade relativa compensada (%)
# 8                                       Horas de sol
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jan  \
# 0                                               34.3
# 1                                                 31
# 2                                               26.9
# 3                                               23.8
# 4                                               19.8
# 5                                               76.9
# 6                                                  9
# 7                                               78.7
# 8                                              234.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Fev  \
# 0                                               34.7
# 1                                               31.1
# 2                                               27.1
# 3                                                 24
# 4                                               19.5
# 5                                               98.7
# 6                                                  9
# 7                                               79.4
# 8                                              208.2
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Mar  \
# 0                                                 37
# 1                                               30.9
# 2                                               27.1
# 3                                               24.1
# 4                                               18.7
# 5                                              147.3
# 6                                                 11
# 7                                               80.6
# 8                                              225.5
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Abr  \
# 0                                               34.5
# 1                                               29.6
# 2                                               26.4
# 3                                               23.6
# 4                                               18.7
# 5                                              284.9
# 6                                                 16
# 7                                               83.3
# 8                                              185.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Mai  \
# 0                                               31.9
# 1                                               28.1
# 2                                               25.3
# 3                                               22.8
# 4                                                 18
# 5                                              302.2
# 6                                                 18
# 7                                               85.1
# 8                                              156.7
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jun  \
# 0                                               30.6
# 1                                               27.1
# 2                                               24.3
# 3                                               21.9
# 4                                               18.2
# 5                                              237.6
# 6                                                 19
# 7                                               84.9
# 8                                              144.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jul  \
# 0                                               30.7
# 1                                               26.6
# 2                                               23.7
# 3                                               21.1
# 4                                               17.5
# 5                                              194.1
# 6                                                 18
# 7                                               83.4
# 8                                              169.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Ago  \
# 0                                               31.3
# 1                                               26.7
# 2                                               23.6
# 3                                                 21
# 4                                               17.7
# 5                                              129.7
# 6                                                 16
# 7                                               82.1
# 8                                              190.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Set  \
# 0                                               30.7
# 1                                               27.7
# 2                                               24.3
# 3                                               21.5
# 4                                               17.6
# 5                                               99.3
# 6                                                 11
# 7                                               81.2
# 8                                              205.3
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Out  \
# 0                                               33.5
# 1                                               29.1
# 2                                               25.4
# 3                                               22.5
# 4                                               18.3
# 5                                                 91
# 6                                                  8
# 7                                                 80
# 8                                              226.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Nov  \
# 0                                               33.5
# 1                                               29.8
# 2                                               26.1
# 3                                               23.1
# 4                                               18.9
# 5                                              108.2
# 6                                                  8
# 7                                               80.4
# 8                                              202.9
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Dez  \
# 0                                               34.3
# 1                                               30.6
# 2                                               26.6
# 3                                               23.5
# 4                                               19.8
# 5                                               63.4
# 6                                                  7
# 7                                               79.3
# 8                                              222.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Ano
# 0                                                 37
# 1                                                 29
# 2                                               25.6
# 3                                               22.7
# 4                                               17.5
# 5                                            1 833,3
# 6                                                150
# 7                                               81.5
# 8                                            2 372,8
# 9  Fonte: INMET (normal climatológica de 1991-202...

# %%
salvador = salvador.drop(9, axis = 0)

# %%
salvador
# Out:
#                                               Medida  \
# 0                    Temperatura máxima recorde (°C)
# 1                      Temperatura máxima média (°C)
# 2                  Temperatura média compensada (°C)
# 3                      Temperatura mínima média (°C)
# 4                    Temperatura mínima recorde (°C)
# 5                                  Precipitação (mm)
# 6                     Dias com precipitação (≥ 1 mm)
# 7                    Umidade relativa compensada (%)
# 8                                       Horas de sol
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jan  \
# 0                                               34.3
# 1                                                 31
# 2                                               26.9
# 3                                               23.8
# 4                                               19.8
# 5                                               76.9
# 6                                                  9
# 7                                               78.7
# 8                                              234.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Fev  \
# 0                                               34.7
# 1                                               31.1
# 2                                               27.1
# 3                                                 24
# 4                                               19.5
# 5                                               98.7
# 6                                                  9
# 7                                               79.4
# 8                                              208.2
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Mar  \
# 0                                                 37
# 1                                               30.9
# 2                                               27.1
# 3                                               24.1
# 4                                               18.7
# 5                                              147.3
# 6                                                 11
# 7                                               80.6
# 8                                              225.5
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Abr  \
# 0                                               34.5
# 1                                               29.6
# 2                                               26.4
# 3                                               23.6
# 4                                               18.7
# 5                                              284.9
# 6                                                 16
# 7                                               83.3
# 8                                              185.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Mai  \
# 0                                               31.9
# 1                                               28.1
# 2                                               25.3
# 3                                               22.8
# 4                                                 18
# 5                                              302.2
# 6                                                 18
# 7                                               85.1
# 8                                              156.7
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jun  \
# 0                                               30.6
# 1                                               27.1
# 2                                               24.3
# 3                                               21.9
# 4                                               18.2
# 5                                              237.6
# 6                                                 19
# 7                                               84.9
# 8                                              144.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Jul  \
# 0                                               30.7
# 1                                               26.6
# 2                                               23.7
# 3                                               21.1
# 4                                               17.5
# 5                                              194.1
# 6                                                 18
# 7                                               83.4
# 8                                              169.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Ago  \
# 0                                               31.3
# 1                                               26.7
# 2                                               23.6
# 3                                                 21
# 4                                               17.7
# 5                                              129.7
# 6                                                 16
# 7                                               82.1
# 8                                              190.4
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Set  \
# 0                                               30.7
# 1                                               27.7
# 2                                               24.3
# 3                                               21.5
# 4                                               17.6
# 5                                               99.3
# 6                                                 11
# 7                                               81.2
# 8                                              205.3
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Out  \
# 0                                               33.5
# 1                                               29.1
# 2                                               25.4
# 3                                               22.5
# 4                                               18.3
# 5                                                 91
# 6                                                  8
# 7                                                 80
# 8                                              226.6
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Nov  \
# 0                                               33.5
# 1                                               29.8
# 2                                               26.1
# 3                                               23.1
# 4                                               18.9
# 5                                              108.2
# 6                                                  8
# 7                                               80.4
# 8                                              202.9
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Dez  \
# 0                                               34.3
# 1                                               30.6
# 2                                               26.6
# 3                                               23.5
# 4                                               19.8
# 5                                               63.4
# 6                                                  7
# 7                                               79.3
# 8                                              222.8
# 9  Fonte: INMET (normal climatológica de 1991-202...
#
#                                                  Ano
# 0                                                 37
# 1                                                 29
# 2                                               25.6
# 3                                               22.7
# 4                                               17.5
# 5                                            1 833,3
# 6                                                150
# 7                                               81.5
# 8                                            2 372,8
# 9  Fonte: INMET (normal climatológica de 1991-202...

# %%
salvador.index = salvador['Medida']

# %%
salvador
# Out:
#                                                               Medida    Jan  \
# Medida
# Temperatura máxima recorde (°C)      Temperatura máxima recorde (°C)   34.3
# Temperatura máxima média (°C)          Temperatura máxima média (°C)     31
# Temperatura média compensada (°C)  Temperatura média compensada (°C)   26.9
# Temperatura mínima média (°C)          Temperatura mínima média (°C)   23.8
# Temperatura mínima recorde (°C)      Temperatura mínima recorde (°C)   19.8
# Precipitação (mm)                                  Precipitação (mm)   76.9
# Dias com precipitação (≥ 1 mm)        Dias com precipitação (≥ 1 mm)      9
# Umidade relativa compensada (%)      Umidade relativa compensada (%)   78.7
# Horas de sol                                            Horas de sol  234.8
#
#                                      Fev    Mar    Abr    Mai    Jun    Jul  \
# Medida
# Temperatura máxima recorde (°C)     34.7     37   34.5   31.9   30.6   30.7
# Temperatura máxima média (°C)       31.1   30.9   29.6   28.1   27.1   26.6
# Temperatura média compensada (°C)   27.1   27.1   26.4   25.3   24.3   23.7
# Temperatura mínima média (°C)         24   24.1   23.6   22.8   21.9   21.1
# Temperatura mínima recorde (°C)     19.5   18.7   18.7     18   18.2   17.5
# Precipitação (mm)                   98.7  147.3  284.9  302.2  237.6  194.1
# Dias com precipitação (≥ 1 mm)         9     11     16     18     19     18
# Umidade relativa compensada (%)     79.4   80.6   83.3   85.1   84.9   83.4
# Horas de sol                       208.2  225.5  185.4  156.7  144.6  169.6
#
#                                      Ago    Set    Out    Nov    Dez      Ano
# Medida
# Temperatura máxima recorde (°C)     31.3   30.7   33.5   33.5   34.3       37
# Temperatura máxima média (°C)       26.7   27.7   29.1   29.8   30.6       29
# Temperatura média compensada (°C)   23.6   24.3   25.4   26.1   26.6     25.6
# Temperatura mínima média (°C)         21   21.5   22.5   23.1   23.5     22.7
# Temperatura mínima recorde (°C)     17.7   17.6   18.3   18.9   19.8     17.5
# Precipitação (mm)                  129.7   99.3     91  108.2   63.4  1 833,3
# Dias com precipitação (≥ 1 mm)        16     11      8      8      7      150
# Umidade relativa compensada (%)     82.1   81.2     80   80.4   79.3     81.5
# Horas de sol                       190.4  205.3  226.6  202.9  222.8  2 372,8

# %%
salvador.drop('Medida', axis = 1, inplace = True)

# %%
salvador
# Out:
#                                      Jan    Fev    Mar    Abr    Mai    Jun  \
# Medida
# Temperatura máxima recorde (°C)     34.3   34.7     37   34.5   31.9   30.6
# Temperatura máxima média (°C)         31   31.1   30.9   29.6   28.1   27.1
# Temperatura média compensada (°C)   26.9   27.1   27.1   26.4   25.3   24.3
# Temperatura mínima média (°C)       23.8     24   24.1   23.6   22.8   21.9
# Temperatura mínima recorde (°C)     19.8   19.5   18.7   18.7     18   18.2
# Precipitação (mm)                   76.9   98.7  147.3  284.9  302.2  237.6
# Dias com precipitação (≥ 1 mm)         9      9     11     16     18     19
# Umidade relativa compensada (%)     78.7   79.4   80.6   83.3   85.1   84.9
# Horas de sol                       234.8  208.2  225.5  185.4  156.7  144.6
#
#                                      Jul    Ago    Set    Out    Nov    Dez  \
# Medida
# Temperatura máxima recorde (°C)     30.7   31.3   30.7   33.5   33.5   34.3
# Temperatura máxima média (°C)       26.6   26.7   27.7   29.1   29.8   30.6
# Temperatura média compensada (°C)   23.7   23.6   24.3   25.4   26.1   26.6
# Temperatura mínima média (°C)       21.1     21   21.5   22.5   23.1   23.5
# Temperatura mínima recorde (°C)     17.5   17.7   17.6   18.3   18.9   19.8
# Precipitação (mm)                  194.1  129.7   99.3     91  108.2   63.4
# Dias com precipitação (≥ 1 mm)        18     16     11      8      8      7
# Umidade relativa compensada (%)     83.4   82.1   81.2     80   80.4   79.3
# Horas de sol                       169.6  190.4  205.3  226.6  202.9  222.8
#
#                                        Ano
# Medida
# Temperatura máxima recorde (°C)         37
# Temperatura máxima média (°C)           29
# Temperatura média compensada (°C)     25.6
# Temperatura mínima média (°C)         22.7
# Temperatura mínima recorde (°C)       17.5
# Precipitação (mm)                  1 833,3
# Dias com precipitação (≥ 1 mm)         150
# Umidade relativa compensada (%)       81.5
# Horas de sol                       2 372,8

# %%
from google.colab.data_table import DataTable

# %%
DataTable(salvador)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Jan</th>
#       <th>Fev</th>
#       <th>Mar</th>
#       <th>Abr</th>
#       <th>Mai</th>
#       <th>Jun</th>
#       <th>Jul</th>
#       <th>Ago</th>
#       <th>Set</th>
#       <th>Out</th>
#       <th>Nov</th>
#       <th>Dez</th>
#       <th>Ano</th>
#     </tr>
#     <tr>
#       <th>Medida</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Temperatura máxima recorde (°C)</th>
#       <td>34.3</td>
#       <td>34.7</td>
#       <td>37</td>
#       <td>34.5</td>
#       <td>31.9</td>
#       <td>30.6</td>
#       <td>30.7</td>
#       <td>31.3</td>
#       <td>30.7</td>
#       <td>33.5</td>
#       <td>33.5</td>
#       <td>34.3</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>Temperatura máxima média (°C)</th>
#       <td>31</td>
#       <td>31.1</td>
#       <td>30.9</td>
#       <td>29.6</td>
#       <td>28.1</td>
#       <td>27.1</td>
#       <td>26.6</td>
#       <td>26.7</td>
#       <td>27.7</td>
#       <td>29.1</td>
#       <td>29.8</td>
#       <td>30.6</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>Temperatura média compensada (°C)</th>
#       <td>26.9</td>
#       <td>27.1</td>
#       <td>27.1</td>
#       <td>26.4</td>
#       <td>25.3</td>
#       <td>24.3</td>
#       <td>23.7</td>
#       <td>23.6</td>
#       <td>24.3</td>
#       <td>25.4</td>
#       <td>26.1</td>
#       <td>26.6</td>
#       <td>25.6</td>
#     </tr>
#     <tr>
#       <th>Temperatura mínima média (°C)</th>
#       <td>23.8</td>
#       <td>24</td>
#       <td>24.1</td>
#       <td>23.6</td>
#       <td>22.8</td>
#       <td>21.9</td>
#       <td>21.1</td>
#       <td>21</td>
#       <td>21.5</td>
#       <td>22.5</td>
#       <td>23.1</td>
#       <td>23.5</td>
#       <td>22.7</td>
#     </tr>
#     <tr>
#       <th>Temperatura mínima recorde (°C)</th>
#       <td>19.8</td>
#       <td>19.5</td>
#       <td>18.7</td>
#       <td>18.7</td>
#       <td>18</td>
#       <td>18.2</td>
#       <td>17.5</td>
#       <td>17.7</td>
#       <td>17.6</td>
#       <td>18.3</td>
#       <td>18.9</td>
#       <td>19.8</td>
#       <td>17.5</td>
#     </tr>
#     <tr>
#       <th>Precipitação (mm)</th>
#       <td>76.9</td>
#       <td>98.7</td>
#       <td>147.3</td>
#       <td>284.9</td>
#       <td>302.2</td>
#       <td>237.6</td>
#       <td>194.1</td>
#       <td>129.7</td>
#       <td>99.3</td>
#       <td>91</td>
#       <td>108.2</td>
#       <td>63.4</td>
#       <td>1 833,3</td>
#     </tr>
#     <tr>
#       <th>Dias com precipitação (≥ 1 mm)</th>
#       <td>9</td>
#       <td>9</td>
#       <td>11</td>
#       <td>16</td>
#       <td>18</td>
#       <td>19</td>
#       <td>18</td>
#       <td>16</td>
#       <td>11</td>
#       <td>8</td>
#       <td>8</td>
#       <td>7</td>
#       <td>150</td>
#     </tr>
#     <tr>
#       <th>Umidade relativa compensada (%)</th>
#       <td>78.7</td>
#       <td>79.4</td>
#       <td>80.6</td>
#       <td>83.3</td>
#       <td>85.1</td>
#       <td>84.9</td>
#       <td>83.4</td>
#       <td>82.1</td>
#       <td>81.2</td>
#       <td>80</td>
#       <td>80.4</td>
#       <td>79.3</td>
#       <td>81.5</td>
#     </tr>
#     <tr>
#       <th>Horas de sol</th>
#       <td>234.8</td>
#       <td>208.2</td>
#       <td>225.5</td>
#       <td>185.4</td>
#       <td>156.7</td>
#       <td>144.6</td>
#       <td>169.6</td>
#       <td>190.4</td>
#       <td>205.3</td>
#       <td>226.6</td>
#       <td>202.9</td>
#       <td>222.8</td>
#       <td>2 372,8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
DataTable(provas)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>P1</th>
#       <th>P2</th>
#       <th>P3</th>
#       <th>P4</th>
#       <th>MF</th>
#       <th>Situação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Alice</th>
#       <td>8.7</td>
#       <td>9.3</td>
#       <td>7.6</td>
#       <td>9.0</td>
#       <td>8.6</td>
#       <td>Aprovado</td>
#     </tr>
#     <tr>
#       <th>Bruno</th>
#       <td>2.3</td>
#       <td>6.7</td>
#       <td>0.2</td>
#       <td>6.5</td>
#       <td>3.9</td>
#       <td>Reprovado</td>
#     </tr>
#     <tr>
#       <th>Carla</th>
#       <td>3.1</td>
#       <td>4.7</td>
#       <td>6.8</td>
#       <td>6.6</td>
#       <td>5.3</td>
#       <td>Aprovado</td>
#     </tr>
#     <tr>
#       <th>David</th>
#       <td>0.3</td>
#       <td>1.9</td>
#       <td>9.5</td>
#       <td>0.3</td>
#       <td>3.0</td>
#       <td>Reprovado</td>
#     </tr>
#     <tr>
#       <th>Emily</th>
#       <td>9.8</td>
#       <td>9.6</td>
#       <td>8.6</td>
#       <td>8.8</td>
#       <td>9.2</td>
#       <td>Aprovado</td>
#     </tr>
#   </tbody>
# </table>
# </div>
